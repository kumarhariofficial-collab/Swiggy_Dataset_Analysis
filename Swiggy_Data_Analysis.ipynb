# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
swiggy = pd.read_csv("Swiggy_Data_1.csv")
swiggy
# Out:
#             State       City  Order_Date           Restaurant_Name  \
# 0       Karnataka  Bengaluru  29-06-2025  Anand Sweets & Savouries
# 1       Karnataka  Bengaluru  03-04-2025     Srinidhi Sagar Deluxe
# 2       Karnataka  Bengaluru  15-01-2025     Srinidhi Sagar Deluxe
# 3       Karnataka  Bengaluru  17-04-2025     Srinidhi Sagar Deluxe
# 4       Karnataka  Bengaluru  13-03-2025     Srinidhi Sagar Deluxe
# ...           ...        ...         ...                       ...
# 197425     Sikkim    Gangtok  25-01-2025            Mama's Kitchen
# 197426     Sikkim    Gangtok  02-07-2025            Mama's Kitchen
# 197427     Sikkim    Gangtok  25-03-2025            Mama's Kitchen
# 197428     Sikkim    Gangtok  26-03-2025            Mama's Kitchen
# 197429     Sikkim    Gangtok  27-03-2025            Mama's Kitchen
#
#                     Location     Category  \
# 0       Rajarajeshwari Nagar        Snack
# 1                    Kengeri  Recommended
# ...

# %%
swiggy.shape
# Out:
# (197430, 10)

# %%
swiggy.info
# Out:
# <bound method DataFrame.info of             State       City  Order_Date           Restaurant_Name  \
# 0       Karnataka  Bengaluru  29-06-2025  Anand Sweets & Savouries
# 1       Karnataka  Bengaluru  03-04-2025     Srinidhi Sagar Deluxe
# 2       Karnataka  Bengaluru  15-01-2025     Srinidhi Sagar Deluxe
# 3       Karnataka  Bengaluru  17-04-2025     Srinidhi Sagar Deluxe
# 4       Karnataka  Bengaluru  13-03-2025     Srinidhi Sagar Deluxe
# ...           ...        ...         ...                       ...
# 197425     Sikkim    Gangtok  25-01-2025            Mama's Kitchen
# 197426     Sikkim    Gangtok  02-07-2025            Mama's Kitchen
# 197427     Sikkim    Gangtok  25-03-2025            Mama's Kitchen
# 197428     Sikkim    Gangtok  26-03-2025            Mama's Kitchen
# 197429     Sikkim    Gangtok  27-03-2025            Mama's Kitchen
#
#                     Location     Category  \
# 0       Rajarajeshwari Nagar        Snack
# 1                    Kengeri  Recommended
# ...

# %%
swiggy.isnull().sum()
# Out:
# State              0
# City               0
# Order_Date         0
# Restaurant_Name    0
# Location           0
# Category           0
# Dish_Name          0
# Price_INR          0
# Rating             0
# Rating_Count       0
# dtype: int64

# %%
swiggy.dtypes
# Out:
# State               object
# City                object
# Order_Date          object
# Restaurant_Name     object
# Location            object
# Category            object
# Dish_Name           object
# Price_INR          float64
# Rating             float64
# Rating_Count         int64
# dtype: object

# %%
swiggy["City"].unique()
# Out:
# array(['Bengaluru', 'Mumbai', 'Chennai', 'New Delhi', 'Hyderabad',
#        'Kolkata', 'Ahmedabad', 'Jaipur', 'Lucknow', 'Chandigarh',
#        'Indore', 'Patna', 'Bhubaneswar', 'Gurgaon', 'Kochi', 'Ranchi',
#        'Guwahati', 'Raipur', 'Dehradun', 'Shimla', 'Panaji', 'Srinagar',
#        'Agartala', 'Imphal', 'Shillong', 'Kohima', 'Aizawl', 'Gangtok'],
#       dtype=object)

# %%
swiggy.columns = swiggy.columns.str.lower()

# %%
swiggy.head(5)
# Out:
#        state       city  order_date           restaurant_name  \
# 0  Karnataka  Bengaluru  29-06-2025  Anand Sweets & Savouries
# 1  Karnataka  Bengaluru  03-04-2025     Srinidhi Sagar Deluxe
# 2  Karnataka  Bengaluru  15-01-2025     Srinidhi Sagar Deluxe
# 3  Karnataka  Bengaluru  17-04-2025     Srinidhi Sagar Deluxe
# 4  Karnataka  Bengaluru  13-03-2025     Srinidhi Sagar Deluxe
#
#                location     category             dish_name  price_inr  rating  \
# 0  Rajarajeshwari Nagar        Snack  Butter Murukku-200gm      133.9     4.0
# 1               Kengeri  Recommended            Badam Milk       52.0     4.5
# 2               Kengeri  Recommended        Chow Chow Bath      117.0     4.7
# 3               Kengeri  Recommended           Kesari Bath       65.0     4.6
# 4               Kengeri  Recommended            Mix Raitha      130.0     4.0
#
#    rating_count
# 0             0
# 1            25
# 2            48
# 3            65
# 4             0

# %%
swiggy.duplicated().sum()
# Out:
# np.int64(27)

# %%
duplicates = swiggy[swiggy.duplicated()]
print(duplicates)
# Out:
#                  state        city order_date  \
# 10148        Karnataka   Bengaluru 2025-01-27
# 10360        Karnataka   Bengaluru 2025-08-15
# 10569        Karnataka   Bengaluru 2025-08-13
# 10753        Karnataka   Bengaluru 2025-02-27
# 13623        Karnataka   Bengaluru 2025-02-22
# 90690      West Bengal     Kolkata 2025-04-12
# 92018      West Bengal     Kolkata 2025-01-04
# 95053          Gujarat   Ahmedabad 2025-07-13
# 95152          Gujarat   Ahmedabad 2025-05-11
# 96850          Gujarat   Ahmedabad 2025-07-10
# 96894          Gujarat   Ahmedabad 2025-08-19
# 97200          Gujarat   Ahmedabad 2025-08-04
# 97305          Gujarat   Ahmedabad 2025-01-16
# 97336          Gujarat   Ahmedabad 2025-01-17
# 97339          Gujarat   Ahmedabad 2025-01-02
# 97959          Gujarat   Ahmedabad 2025-04-30
# 98152          Gujarat   Ahmedabad 2025-06-19
# 101742       Rajasthan      Jaipur 2025-07-06
# 110550          Punjab  Chandigarh 2025-02-06
# ...

# %%
swiggy = swiggy.drop_duplicates()

# %%
swiggy
# Out:
#             state       city order_date           restaurant_name  \
# 0       Karnataka  Bengaluru 2025-06-29  Anand Sweets & Savouries
# 1       Karnataka  Bengaluru 2025-04-03     Srinidhi Sagar Deluxe
# 2       Karnataka  Bengaluru 2025-01-15     Srinidhi Sagar Deluxe
# 3       Karnataka  Bengaluru 2025-04-17     Srinidhi Sagar Deluxe
# 4       Karnataka  Bengaluru 2025-03-13     Srinidhi Sagar Deluxe
# ...           ...        ...        ...                       ...
# 197425     Sikkim    Gangtok 2025-01-25            Mama's Kitchen
# 197426     Sikkim    Gangtok 2025-07-02            Mama's Kitchen
# 197427     Sikkim    Gangtok 2025-03-25            Mama's Kitchen
# 197428     Sikkim    Gangtok 2025-03-26            Mama's Kitchen
# 197429     Sikkim    Gangtok 2025-03-27            Mama's Kitchen
#
#                     location     category  \
# 0       Rajarajeshwari Nagar        Snack
# 1                    Kengeri  Recommended
# 2                    Kengeri  Recommended
# ...

# %% [markdown]
# ## Convert the Date

# %%
swiggy['order_date'] = pd.to_datetime(swiggy['order_date'],format="%d-%m-%Y")

# %%
swiggy
# Out:
#             state       city order_date           restaurant_name  \
# 0       Karnataka  Bengaluru 2025-06-29  Anand Sweets & Savouries
# 1       Karnataka  Bengaluru 2025-04-03     Srinidhi Sagar Deluxe
# 2       Karnataka  Bengaluru 2025-01-15     Srinidhi Sagar Deluxe
# 3       Karnataka  Bengaluru 2025-04-17     Srinidhi Sagar Deluxe
# 4       Karnataka  Bengaluru 2025-03-13     Srinidhi Sagar Deluxe
# ...           ...        ...        ...                       ...
# 197425     Sikkim    Gangtok 2025-01-25            Mama's Kitchen
# 197426     Sikkim    Gangtok 2025-07-02            Mama's Kitchen
# 197427     Sikkim    Gangtok 2025-03-25            Mama's Kitchen
# 197428     Sikkim    Gangtok 2025-03-26            Mama's Kitchen
# 197429     Sikkim    Gangtok 2025-03-27            Mama's Kitchen
#
#                     location     category  \
# 0       Rajarajeshwari Nagar        Snack
# 1                    Kengeri  Recommended
# 2                    Kengeri  Recommended
# ...

# %% [markdown]
# ## Load the Data to SQL

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"
password = quote_plus("Hari#K2026")
host = "127.0.0.1"
database = "swiggy_db"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}/{database}"
)

print("Connection created successfully!")
# Out:
# Connection created successfully!

# %%
swiggy.to_sql(
    name="swiggy",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 197403
